# %% [markdown]
# # Strings and Unicode

# %%
name = "bhai"
print(name.upper())
# Out:
# BHAI

# %%
name.title()
# Out:
# 'Bhai'

# %%
#shows which index its at
name.find('i')
# Out:
# 3

# %%
#f-strings
minutes = 36
paragraph = f"""Greeting {name.title()},
Thank you for attending tonight,
we will be here for {minutes/60:.2f} hours
long-winded talk,
Goodbye :{name}!"""
print(paragraph)
# Out:
# Greeting Bhai,
# Thank you for attending tonight,
# we will be here for 0.60 hours
# long-winded talk,
# Goodbye :bhai!

# %%
name = input()
time = int(input())

# %% [markdown]
# ### count()

# %%
list = [1,2,3,4,5,6,7,3,9]
list.count(3)
# Out:
# 2

# %% [markdown]
# ### Index()

# %%
list.index(7)
# Out:
# 6
