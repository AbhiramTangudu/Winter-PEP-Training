# %% [markdown]
# # Nested Dictionary

# %%
car1_model={'Mercedes':1960}
car2_model={'BMW':1970}
car3_model={'Audi':1980}
car_type={'car1':car1_model, 'car2':car2_model, 'car3':car3_model}

# %%
print(car_type)
# Out:
# {'car1': {'Mercedes': 1960}, 'car2': {'BMW': 1970}, 'car3': {'Audi': 1980}}

# %%
print(car_type['car3'])
# Out:
# {'Audi': 1980}

# %%
print(car_type['car3']['Audi'])
# Out:
# 1980
