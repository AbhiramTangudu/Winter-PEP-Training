# %% [markdown]
# # Python Asserts

# %% [markdown]
# Python provides the assert statement to check if a given logical expression is true or false.
# program execution proceeds only if the expression is true and raises the assertionerror when
# it is false. Gthe following code shows the usage of the assert statement.

# %%
num=10
assert num>10
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 num=10
# ----> 2 assert num>10
#
# AssertionError:

# %%
try:
    num=int(input("Enter a even number: "))
    assert num%2==0
    print("The number is even")
except AssertionError:
    print("Plz enter even number")
# Out:
# Plz enter even number
